# %%
import pandas as pd

df = pd.read_csv('data/raw/credit_card.csv')

# %%
import yaml
from src.focal_loss import FocalLoss

with open('src/config.yaml', 'r') as file:
    config = yaml.safe_load(file)

focal_tuning = FocalLoss(config)
results, best_params, best_model = focal_tuning._focal_random_search()
# Out:
# Data loaders initialized.
#
# Starting Random Search with 10 out of 25 combinations, running 5 epochs per test. f1_score as decision metric.
#
# Currently testing combination 1/10: [alpha 0.3, gamma 2] ...
# Best results for hyperparameter [alpha: 0.3, gamma: 2] | Precision: 0.000 | Recall: 0.000 | F1: 0.000
#
# Currently testing combination 2/10: [alpha 0.05, gamma 2] ...
# Best results for hyperparameter [alpha: 0.05, gamma: 2] | Precision: 0.000 | Recall: 0.000 | F1: 0.000
#
# Currently testing combination 3/10: [alpha 0.3, gamma 2] ...
# Best results for hyperparameter [alpha: 0.3, gamma: 2] | Precision: 0.908 | Recall: 0.752 | F1: 0.823
#
# Currently testing combination 4/10: [alpha 0.3, gamma 5] ...
# Best results for hyperparameter [alpha: 0.3, gamma: 5] | Precision: 0.869 | Recall: 0.819 | F1: 0.843
#
# Currently testing combination 5/10: [alpha 0.3, gamma 4] ...
# Best results for hyperparameter [alpha: 0.3, gamma: 4] | Precision: 0.934 | Recall: 0.543 | F1: 0.687
#
# Currently testing combination 6/10: [alpha 0.15, gamma 4] ...
# Best results for hyperparameter [alpha: 0.15, gamma: 4] | Precision: 1.000 | Recall: 0.524 | F1: 0.688
#
# Currently testing combination 7/10: [alpha 0.05, gamma 1] ...
# Best results for hyperparameter [alpha: 0.05, gamma: 1] | Precision: 0.000 | Recall: 0.000 | F1: 0.000
#
# Currently testing combination 8/10: [alpha 0.3, gamma 1] ...
# Best results for hyperparameter [alpha: 0.3, gamma: 1] | Precision: 0.000 | Recall: 0.000 | F1: 0.000
#
# Currently testing combination 9/10: [alpha 0.1, gamma 4] ...
# Best results for hyperparameter [alpha: 0.1, gamma: 4] | Precision: 0.000 | Recall: 0.000 | F1: 0.000
#
# Currently testing combination 10/10: [alpha 0.3, gamma 5] ...
# Best results for hyperparameter [alpha: 0.3, gamma: 5] | Precision: 0.883 | Recall: 0.790 | F1: 0.834
#
# Random Search complete.
# Best parameters: {'alpha': 0.3, 'gamma': 5}
# Best f1_score: 0.843
